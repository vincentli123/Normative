# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import os 
os.chdir('/Users/vincentli/Documents/Kaggle/Se_emissions')
df = pd.read_csv('swe_data.csv', index_col = 'sector', sep = ',')
# Out:
#                                                                                    greenhouse gas  \
# sector
# NATIONAL TOTAL (excluding LULUCF, excluding int...           Total Greenhouse Gases (kt CO2-eqv.)
# NATIONAL TOTAL (excluding LULUCF, including int...           Total Greenhouse Gases (kt CO2-eqv.)
# NATIONAL TOTAL (including LULUCF, excluding int...           Total Greenhouse Gases (kt CO2-eqv.)
# NATIONAL TOTAL (including LULUCF, including int...           Total Greenhouse Gases (kt CO2-eqv.)
# OFF-ROAD VEHICLES AND OTHER MACHINERY, TOTAL                 Total Greenhouse Gases (kt CO2-eqv.)
# WASTE, TOTAL                                                 Total Greenhouse Gases (kt CO2-eqv.)
# ELECTRICITY AND DISTRICT HEATING, TOTAL                      Total Greenhouse Gases (kt CO2-eqv.)
# INDUSTRY, TOTAL                                              Total Greenhouse Gases (kt CO2-eqv.)
# ...

# %%
df.columns
# Out:
# Index(['greenhouse gas', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of                                                                                    greenhouse gas  \
# sector
# NATIONAL TOTAL (excluding LULUCF, excluding int...           Total Greenhouse Gases (kt CO2-eqv.)
# NATIONAL TOTAL (excluding LULUCF, including int...           Total Greenhouse Gases (kt CO2-eqv.)
# NATIONAL TOTAL (including LULUCF, excluding int...           Total Greenhouse Gases (kt CO2-eqv.)
# NATIONAL TOTAL (including LULUCF, including int...           Total Greenhouse Gases (kt CO2-eqv.)
# OFF-ROAD VEHICLES AND OTHER MACHINERY, TOTAL                 Total Greenhouse Gases (kt CO2-eqv.)
# WASTE, TOTAL                                                 Total Greenhouse Gases (kt CO2-eqv.)
# ELECTRICITY AND DISTRICT HEATING, TOTAL                      Total Greenhouse Gases (kt CO2-eqv.)
# INDUSTRY, TOTAL                                              Total Greenhouse Gases (kt CO2-eqv.)
# ...

# %%
df.describe()
# Out:
#                                   greenhouse gas 1990 1991 1992 1993 1994  \
# count                                        154  154  154  154  154  154
# unique                                        11   96   98   98   98   98
# top     Sulphur Hexafluoride (SF6) (kt CO2-eqv.)   ..   ..   ..   ..   ..
# freq                                          14   42   41   41   41   41
#
#        1995 1996 1997 1998  ... 2009 2010 2011 2012 2013 2014 2015 2016 2017  \
# count   154  154  154  154  ...  154  154  154  154  154  154  154  154  154
# unique  100  100  100  100  ...   99  100  100  102  102  100  100  100  100
# top      ..   ..   ..   ..  ...   ..   ..   ..   ..   ..   ..   ..   ..   ..
# freq     40   40   40   40  ...   39   39   39   38   38   39   39   39   38
#
#        2018
# count   154
# unique   98
# top      ..
# freq     40
#
# [4 rows x 30 columns]

# %%
df.index.dtype
# Out:
# dtype('O')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 154 entries, NATIONAL TOTAL (excluding LULUCF, excluding international transports) to LAND-USE, LAND-USE CHANGE AND FORESTRY (LULUCF), TOTAL
# Data columns (total 30 columns):
# greenhouse gas    154 non-null object
# 1990              154 non-null object
# 1991              154 non-null object
# 1992              154 non-null object
# 1993              154 non-null object
# 1994              154 non-null object
# 1995              154 non-null object
# 1996              154 non-null object
# 1997              154 non-null object
# 1998              154 non-null object
# 1999              154 non-null object
# 2000              154 non-null object
# 2001              154 non-null object
# 2002              154 non-null object
# 2003              154 non-null object
# 2004              154 non-null object
# 2005              154 non-null object
# 2006              154 non-null object
# 2007              154 non-null object
# ...

# %%
df.isnull().sum()
# Out:
# greenhouse gas    0
# 1990              0
# 1991              0
# 1992              0
# 1993              0
# 1994              0
# 1995              0
# 1996              0
# 1997              0
# 1998              0
# 1999              0
# 2000              0
# 2001              0
# 2002              0
# 2003              0
# 2004              0
# 2005              0
# 2006              0
# 2007              0
# 2008              0
# 2009              0
# 2010              0
# 2011              0
# 2012              0
# 2013              0
# 2014              0
# 2015              0
# 2016              0
# 2017              0
# 2018              0
# dtype: int64

# %%
df.dtypes
# Out:
# greenhouse gas    object
# 1990              object
# 1991              object
# 1992              object
# 1993              object
# 1994              object
# 1995              object
# 1996              object
# 1997              object
# 1998              object
# 1999              object
# 2000              object
# 2001              object
# 2002              object
# 2003              object
# 2004              object
# 2005              object
# 2006              object
# 2007              object
# 2008              object
# 2009              object
# 2010              object
# 2011              object
# 2012              object
# 2013              object
# 2014              object
# 2015              object
# 2016              object
# 2017              object
# 2018              object
# dtype: object

# %%
df[['1990', '1991', '1992', '1993', '1994',
       '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
       '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
       '2013', '2014', '2015', '2016', '2017', '2018']] = df[['1990', '1991', '1992', '1993', '1994',
       '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
       '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
       '2013', '2014', '2015', '2016', '2017', '2018']].apply(pd.to_numeric, errors = 'coerce')

#get rid of na
df = df.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

#checking which columns give the total greenhouse gases amount
sum_check_df = df.loc['NATIONAL TOTAL (including LULUCF, including international transports)'] 
sum_check_df.set_index('greenhouse gas') 

#calculating difference for 1990 - this difference is the amount in the column biogenic carbon dioxide
sum_check_df_t = sum_check_df.T
tgg = sum_check_df_t.iloc[1,0]
tgg_sum = sum_check_df_t.iloc[1, 1:].sum()
tgg_sum_kgt = sum_check_df_t.iloc[1, 3:10:3].sum()
diff = tgg - (tgg_sum - tgg_sum_kgt)
#percentage_diff = round(diff/tgg*100) 
#percentage_diff = str(percentage_diff) + '%'
#sum_check_df_t 

#calculating difference for whole dataset
tgg_col = sum_check_df_t.iloc[1:, 0]

#only keeping columns that have kt to check that the total emissions are close to the sum of the other emissions
tgg_cols = sum_check_df_t.iloc[1:, 1:].sum().sum()
tgg_kgt = sum_check_df_t.iloc[1:, 3:6:10].sum().sum()
bco2_col = sum_check_df_t.iloc[1:,2].sum()
tgg_cols_kt = tgg_cols - tgg_kgt - bco2_col
bco2_col = sum_check_df_t.iloc[1:,2].sum()
#tgg_cols_kt = tgg_cols_kt - total_kg - bco2_col
tgg_col = sum_check_df_t.iloc[1:,0].sum()

#summing columns that are in kt and then subtracting it from the total column
tgg_cols = sum_check_df_t.iloc[1:,1].sum() + sum_check_df_t.iloc[1:,4].sum() + sum_check_df_t.iloc[1:,5].sum() + sum_check_df_t.iloc[1:,7].sum()
+ sum_check_df_t.iloc[1:,8].sum() + sum_check_df_t.iloc[1:,10].sum()
diff = tgg_cols_kt - tgg_col
percentage_diff = round((tgg_col-tgg_cols)/tgg_cols*100)
percentage_diff = str(percentage_diff) + '%'
#df_tgg = sum_check_df_t[sum_check_df[1]]
 
print('\n sum of total greenhouse gas emissions is ', tgg_col, 'kt',
    '\n sum of total greenhouse gas emissions from other columns is ', tgg_cols, 'kt',
    '\n percentage difference between these two values is', percentage_diff)


#sum_check_df_t
# Out:
#  sum of total greenhouse gas emissions is  976260.6 kt
#  sum of total greenhouse gas emissions from other columns is  964453.1 kt
#  percentage difference between these two values is 1%

# %%
#calculating percentage of each greenhouse gas on total emissions

co2_sum = sum_check_df_t.iloc[1:, 1].sum()
n2o_sum = sum_check_df_t.iloc[1:, 4].sum()
ch4_sum = sum_check_df_t.iloc[1:, 5].sum()
hfc_sum = sum_check_df_t.iloc[1:, 7].sum()
pfc_sum = sum_check_df_t.iloc[1:, 8].sum()
sf6_sum = sum_check_df_t.iloc[1:, 10].sum()

co2_percent = round(co2_sum/tgg_col*100)
n2o_percent = round(n2o_sum/tgg_col*100)
ch4_percent = round(ch4_sum/tgg_col*100)
hfc_percent = round(hfc_sum/tgg_col*100)
pfc_percent = round(pfc_sum/tgg_col*100)
sf6_percent = round(sf6_sum/tgg_col*100, 2)

print('\n percentage of co2 is', co2_percent, '%',
     '\n percentage of n2o is', n2o_percent, '%',
     '\n percentage of ch4 is', ch4_percent, '%',
     '\n percentage of hfc is', hfc_percent, '%',
     '\n percentage of pfc is', pfc_percent, '%', 
     '\n percentage of sf6 is', sf6_percent, '%')
# Out:
#  percentage of co2 is 58 %
#  percentage of n2o is 19 %
#  percentage of ch4 is 20 %
#  percentage of hfc is 2 %
#  percentage of pfc is 1 %
#  percentage of sf6 is 0.28 %

# %%
df['greenhouse gas'].value_counts()
# Out:
# Total Greenhouse Gases (kt CO2-eqv.)             14
# Nitrous Oxide (N2O) (kt CO2-eqv.)                14
# Carbon Dioxide (CO2) (kt)                        14
# Nitrous Oxide (N2O) (t)                          14
# Methane (CH4) (t)                                13
# Methane (CH4) (kt CO2-eqv.)                      13
# Biogenic carbon dioxide (CO2) from fuels (kt)     8
# Sulphur Hexafluoride (SF6) (kt CO2-eqv.)          5
# Hydrofluorocarbons (HFCs) (kt CO2-eqv.)           5
# Sulphur Hexafluoride (SF6) (kg)                   5
# Perfluorocarbons (PFCs) (kt CO2-eqv.)             5
# Name: greenhouse gas, dtype: int64

# %%
df.index.value_counts()
# Out:
# NATIONAL TOTAL (including LULUCF, excluding international transports)    11
# NATIONAL TOTAL (including LULUCF, including international transports)    11
# NATIONAL TOTAL (excluding LULUCF, including international transports)    11
# NATIONAL TOTAL (excluding LULUCF, excluding international transports)    11
# INDUSTRY, TOTAL                                                           8
# ELECTRICITY AND DISTRICT HEATING, TOTAL                                   7
# SOLVENT USE AND OTHER PRODUCT USE, TOTAL                                  7
# DOMESTIC TRANSPORT, TOTAL                                                 7
# HEATING OF HOUSES AND PREMISES, TOTAL                                     7
# WASTE, TOTAL                                                              6
# AGRICULTURE, TOTAL                                                        6
# OFF-ROAD VEHICLES AND OTHER MACHINERY, TOTAL                              6
# ...

# %%
#selecting sub-tables based on greenhouse gas

df_co2 = df[df['greenhouse gas'] == 'Carbon Dioxide (CO2) (kt)']
df_hfc = df[df['greenhouse gas'] == 'Hydrofluorocarbons (HFCs) (kt CO2-eqv.)']
df_n2o = df[df['greenhouse gas'] == 'Nitrous Oxide (N2O) (kt CO2-eqv.)']
df_sf6 = df[df['greenhouse gas'] == 'Sulphur Hexafluoride (SF6) (kt CO2-eqv.)']

df_ch4 = df[df['greenhouse gas'] == 'Methane (CH4) (kt CO2-eqv.)']

df_pfc = df[df['greenhouse gas'] == 'Perfluorocarbons (PFCs) (kt CO2-eqv.)']
df_bco = df[df['greenhouse gas'] == 'Biogenic carbon dioxide (CO2) from fuels (kt)']
df_tgg = df[df['greenhouse gas'] == 'Total Greenhouse Gases (kt CO2-eqv.)']

 
df_co2_fl = df_co2[['1990', '1991', '1992', '1993', '1994',
       '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
       '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
       '2013', '2014', '2015', '2016', '2017', '2018']]

df_hfc_fl = df_hfc[['1990', '1991', '1992', '1993', '1994',
        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
        '2013', '2014', '2015', '2016', '2017', '2018']]

df_n2o_fl = df_n2o[['1990', '1991', '1992', '1993', '1994',
        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
        '2013', '2014', '2015', '2016', '2017', '2018']]

df_sf6_fl = df_sf6[['1990', '1991', '1992', '1993', '1994',
        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
        '2013', '2014', '2015', '2016', '2017', '2018']]

df_ch4_fl = df_ch4[['1990', '1991', '1992', '1993', '1994',
        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
        '2013', '2014', '2015', '2016', '2017', '2018']]

df_pfc_fl = df_pfc[['1990', '1991', '1992', '1993', '1994',
        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
        '2013', '2014', '2015', '2016', '2017', '2018']]

df_tgg_fl = df_tgg[['1990', '1991', '1992', '1993', '1994',
        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
        '2013', '2014', '2015', '2016', '2017', '2018']]

df_co2_fl_t = df_co2_fl.T
df_hfc_fl_t = df_hfc_fl.T 
df_tgg_fl_t = df_tgg_fl.T
df_n2o_fl_t = df_n2o_fl.T
df_sf6_fl_t = df_sf6_fl.T
df_ch4_fl_t = df_ch4_fl.T
df_pfc_fl_t = df_pfc_fl.T
#df_bco_fl_t = df_bco_fl.T
df_tgg_fl_t
# Out:
# sector  NATIONAL TOTAL (excluding LULUCF, excluding international transports)  \
# 1990                                              71184.9
# 1991                                              71428.1
# 1992                                              70970.2
# 1993                                              71276.4
# 1994                                              73788.7
# 1995                                              73120.5
# 1996                                              77088.0
# 1997                                              72084.3
# 1998                                              72549.4
# 1999                                              69454.6
# 2000                                              68114.6
# 2001                                              68934.3
# 2002                                              69642.1
# 2003                                              70017.2
# 2004                                              69455.1
# ...

# %%
#df_co2_fl_t_c = df_co2_fl_t.iloc[:,1]

for i in range(len(df_co2_fl_t.columns)):
    plt.figure(figsize = (20,5))
    x_ticks = [j for j in df_co2_fl_t.iloc[:, 1].index]
    plt.xticks(np.arange(len(df_co2_fl_t.iloc[:,1].index)), x_ticks, visible = True, rotation = 'horizontal')
    plt.plot(df_co2_fl_t.iloc[:,1].index, df_co2_fl_t.iloc[:,i])
    plt.title(df_co2_fl_t.iloc[:,i].name + ' CO2 (kt)')

# %%
for i in range(len(df_hfc_fl_t.columns)):
    plt.figure(figsize = (20,5))
    x_ticks = [j for j in df_hfc_fl_t.iloc[:, 1].index]
    plt.xticks(np.arange(len(df_hfc_fl_t.iloc[:,1].index)), x_ticks, visible = True, rotation = 'horizontal')
    plt.plot(df_hfc_fl_t.iloc[:,1].index, df_hfc_fl_t.iloc[:,i])
    plt.title(df_hfc_fl_t.iloc[:,i].name + ' HFCs (kt CO2 eqv)')

# %%
for i in range(len(df_n2o_fl_t.columns)):
    plt.figure(figsize = (20,5))
    x_ticks = [j for j in df_n2o_fl_t.iloc[:, 1].index]
    plt.xticks(np.arange(len(df_n2o_fl_t.iloc[:,1].index)), x_ticks, visible = True, rotation = 'horizontal')
    plt.plot(df_n2o_fl_t.iloc[:,1].index, df_n2o_fl_t.iloc[:,i])
    plt.title(df_n2o_fl_t.iloc[:,i].name + ' N20 (kt CO2 eqv)')

# %%
for i in range(len(df_sf6_fl_t.columns)):
    plt.figure(figsize = (20,5))
    x_ticks = [j for j in df_sf6_fl_t.iloc[:, 1].index]
    plt.xticks(np.arange(len(df_sf6_fl_t.iloc[:,1].index)), x_ticks, visible = True, rotation = 'horizontal')
    plt.plot(df_sf6_fl_t.iloc[:,1].index, df_sf6_fl_t.iloc[:,i])
    plt.title(df_sf6_fl_t.iloc[:,i].name + ' SF6 (kt CO2 eqv)')

# %%
for i in range(len(df_ch4_fl_t.columns)):
    plt.figure(figsize = (20,5))
    x_ticks = [j for j in df_ch4_fl_t.iloc[:, 1].index]
    plt.xticks(np.arange(len(df_ch4_fl_t.iloc[:,1].index)), x_ticks, visible = True, rotation = 'horizontal')
    plt.plot(df_ch4_fl_t.iloc[:,1].index, df_ch4_fl_t.iloc[:,i])
    plt.title(df_ch4_fl_t.iloc[:,i].name + ' CH4 (kt CO2 eqv)')

# %%
for i in range(len(df_pfc_fl_t.columns)):
    plt.figure(figsize = (20,5))
    x_ticks = [j for j in df_pfc_fl_t.iloc[:, 1].index]
    plt.xticks(np.arange(len(df_pfc_fl_t.iloc[:,1].index)), x_ticks, visible = True, rotation = 'horizontal')
    plt.plot(df_pfc_fl_t.iloc[:,1].index, df_pfc_fl_t.iloc[:,i])
    plt.title(df_pfc_fl_t.iloc[:,i].name + ' PFCs (kt CO2 eqv)')

# %%
for i in range(len(df_tgg_fl_t.columns)):
    plt.figure(figsize = (20,5))
    x_ticks = [j for j in df_tgg_fl_t.iloc[:, 1].index]
    plt.xticks(np.arange(len(df_tgg_fl_t.iloc[:,1].index)), x_ticks, visible = True, rotation = 'horizontal')
    plt.plot(df_tgg_fl_t.iloc[:,1].index, df_tgg_fl_t.iloc[:,i])
    plt.title(df_tgg_fl_t.iloc[:,i].name + ' Total Greenhouse Gases (kt CO2 eqv)')

# %%
""""
The total greenhouse gas emissions have kept decreasing overall since 1990 for all categories except for international 
transport and and solvents. International transport emissions increase in all categories. 
HFC emissions are the only ones that appear to increase since 1990 since they are mostly used
in the solvent industry according to the data. 
CO2 emissions increase for waste, international transport and solvents.
SF6 and PFCs emissions decrease in all categories and CH4 emissions increase only for electricity, 
international transport and land use.

""""

# %%
df_tgg_fl_t.describe()
# Out:
# sector  NATIONAL TOTAL (excluding LULUCF, excluding international transports)  \
# count                                           29.000000
# mean                                         65214.679310
# std                                           7556.022395
# min                                          51779.200000
# 25%                                          58496.800000
# 50%                                          68114.600000
# 75%                                          71184.900000
# max                                          77088.000000
#
# sector  NATIONAL TOTAL (excluding LULUCF, including international transports)  \
# count                                           29.000000
# mean                                         72470.851724
# std                                           6190.705448
# min                                          61825.600000
# 25%                                          67960.900000
# ...

# %%
df_co2_fl_t.describe()
# Out:
# sector  NATIONAL TOTAL (excluding LULUCF, excluding international transports)  \
# count                                           29.000000
# mean                                         52831.941379
# std                                           6206.888339
# min                                          41766.200000
# 25%                                          47231.100000
# 50%                                          54684.400000
# 75%                                          57451.500000
# max                                          63302.800000
#
# sector  NATIONAL TOTAL (excluding LULUCF, including international transports)  \
# count                                           29.000000
# mean                                         59977.879310
# std                                           4930.144214
# min                                          51211.400000
# 25%                                          56555.400000
# ...

# %%
df_ch4_fl_t.describe()
# Out:
# sector  NATIONAL TOTAL (excluding LULUCF, excluding international transports)  \
# count                                           29.000000
# mean                                          6130.841379
# std                                           1129.322370
# min                                           4380.500000
# 25%                                           5066.000000
# 50%                                           6303.900000
# 75%                                           7305.900000
# max                                           7550.000000
#
# sector  NATIONAL TOTAL (excluding LULUCF, including international transports)  \
# count                                           29.000000
# mean                                          6132.189655
# std                                           1129.049338
# min                                           4382.500000
# 25%                                           5067.600000
# ...

# %%
df_n2o_fl_t.describe()
# Out:
# sector  NATIONAL TOTAL (excluding LULUCF, excluding international transports)  \
# count                                           29.000000
# mean                                          5078.241379
# std                                            444.867423
# min                                           4483.000000
# 25%                                           4654.500000
# 50%                                           5059.400000
# 75%                                           5583.900000
# max                                           5740.300000
#
# sector  NATIONAL TOTAL (excluding LULUCF, including international transports)  \
# count                                           29.000000
# mean                                          5187.106897
# std                                            419.950936
# min                                           4598.600000
# 25%                                           4792.500000
# ...

# %%
df_sf6_fl_t.describe()
# Out:
# sector  NATIONAL TOTAL (excluding LULUCF, excluding international transports)  \
# count                                           29.000000
# mean                                            92.786207
# std                                             35.313461
# min                                             32.100000
# 25%                                             57.500000
# 50%                                            101.700000
# 75%                                            118.800000
# max                                            159.600000
#
# sector  NATIONAL TOTAL (excluding LULUCF, including international transports)  \
# count                                           29.000000
# mean                                            92.786207
# std                                             35.313461
# min                                             32.100000
# 25%                                             57.500000
# ...

# %%
df_hfc_fl_t.describe()
# Out:
# sector  NATIONAL TOTAL (excluding LULUCF, excluding international transports)  \
# count                                           29.000000
# mean                                           766.524138
# std                                            446.271271
# min                                              6.500000
# 25%                                            371.900000
# 50%                                           1034.900000
# 75%                                           1110.200000
# max                                           1155.900000
#
# sector  NATIONAL TOTAL (excluding LULUCF, including international transports)  \
# count                                           29.000000
# mean                                           766.524138
# std                                            446.271271
# min                                              6.500000
# 25%                                            371.900000
# ...

# %%
df_pfc_fl_t.describe()
# Out:
# sector  NATIONAL TOTAL (excluding LULUCF, excluding international transports)  \
# count                                           29.000000
# mean                                           314.358621
# std                                            182.389394
# min                                             31.200000
# 25%                                             82.000000
# 50%                                            392.200000
# 75%                                            433.700000
# max                                            573.800000
#
# sector  NATIONAL TOTAL (excluding LULUCF, including international transports)  \
# count                                           29.000000
# mean                                           314.358621
# std                                            182.389394
# min                                             31.200000
# 25%                                             82.000000
# ...

# %%
df_tgg_fl_t.describe()
# Out:
# sector  NATIONAL TOTAL (excluding LULUCF, excluding international transports)  \
# count                                           29.000000
# mean                                         65214.679310
# std                                           7556.022395
# min                                          51779.200000
# 25%                                          58496.800000
# 50%                                          68114.600000
# 75%                                          71184.900000
# max                                          77088.000000
#
# sector  NATIONAL TOTAL (excluding LULUCF, including international transports)  \
# count                                           29.000000
# mean                                         72470.851724
# std                                           6190.705448
# min                                          61825.600000
# 25%                                          67960.900000
# ...

# %%
"""
When looking at National Total including LULUCF and international transport for individual gases:
CO2 is by far the most emitted greenhouse gas, accounting for 58% of emissions, 
CH4 and N20 represent 20% and 19% of emissions respectively and HFCs, PFCs and SF6 the remaining 2-3%. 
CO2 also has the highest standard deviation, which is 7 times higher than the standard deviation of CH4,
the highest maximum value and the highest quartiles, which are more than double the ones of CH4. 
N2O's standard deviation is less than half that of CH4 and the quartiles are similar to CH4. 
The other gases have smaller values with HFC having the highest values and SF6 the lowest. 

"""

# %%
df_csv = df.to_csv('df_emissions.csv', index = True)

# %%
from pymongo import MongoClient
data = pd.read_csv('df_emissions.csv')
client = MongoClient('mongodb://mdb-user:mdb75@cluster0-shard-00-00.unkec.mongodb.net:27017,cluster0-shard-00-01.unkec.mongodb.net:27017,cluster0-shard-00-02.unkec.mongodb.net:27017/database?ssl=true&replicaSet=atlas-14mpfi-shard-0&authSource=admin&retryWrites=true&w=majority')

db = client['database']
collection = db['collection2']

data.reset_index(inplace=True)
data_dict = data.to_dict("records")

collection.insert_many(data_dict)

# %%
mongo_docs = collection.count()
#for doc in mongo_docs:
#    _id = doc["_id"]
#    print (doc)

print (mongo_docs)
# Out:
# 110
# /Users/vincentli/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   if __name__ == '__main__':

# %%
df.columns
# Out:
# Index(['greenhouse gas', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018'],
#       dtype='object')

# %%
import sqlite3
conn = sqlite3.connect('Emissions.db')
c = conn.cursor()

c.execute('CREATE TABLE EMISSIONS (greenhouse gas, ´1990´, ´1991´, ´1992´, ´1993´, ´1994´, ´1995´,'
       '´1996´, ´1997´, ´1998´, ´1999´, ´2000´, ´2001´, ´2002´, ´2003´, ´2004´,'
       '´2005´, ´2006´, ´2007´, ´2008´, ´2009´, ´2010´, ´2011´, ´2012´, ´2013´,'
       '´2014´, ´2015´, ´2016´, ´2017´, ´2018´)')  

conn.commit()

# %%
df.to_sql('Emissions', conn, if_exists='replace', index = False)

# %%
result = c.execute('''  
SELECT * FROM EMISSIONS
          ''')
df_fromsql = pd.DataFrame(c.fetchall(), columns = ['greenhouse gas', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018'])
c.close()
print(df_fromsql)
# Out:
#                                     greenhouse gas     1990     1991     1992  \
# 0             Total Greenhouse Gases (kt CO2-eqv.)  71184.9  71428.1  70970.2
# 1             Total Greenhouse Gases (kt CO2-eqv.)  74916.7  75188.7  74882.6
# 2             Total Greenhouse Gases (kt CO2-eqv.)  36697.1  37829.5  37527.3
# 3             Total Greenhouse Gases (kt CO2-eqv.)  40428.9  41590.1  41439.7
# 4             Total Greenhouse Gases (kt CO2-eqv.)   3305.6   3098.2   3499.4
# 5             Total Greenhouse Gases (kt CO2-eqv.)   3742.3   3807.8   3819.8
# 6             Total Greenhouse Gases (kt CO2-eqv.)   6484.4   7509.1   7997.2
# 7             Total Greenhouse Gases (kt CO2-eqv.)  20761.2  20537.2  19089.1
# 8             Total Greenhouse Gases (kt CO2-eqv.)  19387.0  19551.2  20466.5
# 9             Total Greenhouse Gases (kt CO2-eqv.)   3731.8   3760.6   3912.4
# 10            Total Greenhouse Gases (kt CO2-eqv.)   7641.1   7315.6   7266.6
# ...

# %%
df_emissions = pd.read_csv('df_emissions.csv')
df_emissions
# Out:
#                                                 sector  \
# 0    NATIONAL TOTAL (excluding LULUCF, excluding in...
# 1    NATIONAL TOTAL (excluding LULUCF, including in...
# 2    NATIONAL TOTAL (including LULUCF, excluding in...
# 3    NATIONAL TOTAL (including LULUCF, including in...
# 4         OFF-ROAD VEHICLES AND OTHER MACHINERY, TOTAL
# 5                                         WASTE, TOTAL
# 6              ELECTRICITY AND DISTRICT HEATING, TOTAL
# 7                                      INDUSTRY, TOTAL
# 8                            DOMESTIC TRANSPORT, TOTAL
# 9                       INTERNATIONAL TRANSPORT, TOTAL
# 10                                  AGRICULTURE, TOTAL
# 11            SOLVENT USE AND OTHER PRODUCT USE, TOTAL
# 12               HEATING OF HOUSES AND PREMISES, TOTAL
# 13   LAND-USE, LAND-USE CHANGE AND FORESTRY (LULUCF...
# 14   NATIONAL TOTAL (excluding LULUCF, excluding in...
# 15   NATIONAL TOTAL (excluding LULUCF, including in...
# ...

# %%
import mysql.connector
import boto3
import sys
import os

ENDPOINT = 'database-2.cqrdogtep225.us-east-1.rds.amazonaws.com'
PORT = '3306'
USR = 'admin'
REGION = 'us-east-1'
PASSWORD= 'admindb7'
DBNAME = 'db1'
os.environ['LIBMYSQL_ENABLE_CLEARTEXT_PLUGIN'] = '1'

#session = boto3.Session(profile_name = 'default', aws_access_key_id=ACCESS_KEY, aws_secret_access_key=SECRET_KEY)

#client = boto3.client('rds', 'us-east-1', aws_access_key_id=ACCESS_KEY, aws_secret_access_key=SECRET_KEY)

#token = client.generate_db_auth_token(DBHostname=ENDPOINT, Port=PORT, DBUsername=USR, Region=REGION)


try:
    conn =  mysql.connector.connect(host=ENDPOINT, user=USR, passwd=PASSWORD, port=PORT, database=DBNAME)
    cur = conn.cursor()
    cur.execute("""SELECT * from db1.df_emissions limit 5""")
    query_results = cur.fetchall()
    print(query_results)
except Exception as e:
    print("Database connection failed due to {}".format(e))
# Out:
# [('sector', 'greenhouse gas', 1990.0, 1991.0, 1992.0, 1993.0, 1994.0, 1995.0, 1996.0, 1997.0, 1998.0, 1999.0, 2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2018.0), ('NATIONAL TOTAL (excluding LULUCF, excluding international transports)', 'Total Greenhouse Gases (kt CO2-eqv.)', 71184.9, 71428.1, 70970.2, 71276.4, 73788.7, 73120.5, 77088.0, 72084.3, 72549.4, 69454.6, 68114.6, 68934.3, 69642.1, 70017.2, 69455.1, 66624.0, 66247.4, 65129.2, 62753.4, 58496.8, 64467.3, 60131.5, 57294.3, 55607.7, 53846.4, 53739.2, 53285.9, 52715.0, 51779.2), ('NATIONAL TOTAL (excluding LULUCF, including international transports)', 'Total Greenhouse Gases (kt CO2-eqv.)', 74916.7, 75188.7, 74882.6, 75436.6, 78587.9, 77998.1, 82195.0, 78010.0, 79354.5, 76419.3, 74979.2, 75630.4, 75495.0, 77315.4, 77875.5, 75324.6, 75458.0, 74459.2, 72138.3, 67960.9, 73553.1, 68274.9, 65080.7, 63130.7, 61841.3, 61825.6, 62302.8, 62
# ...
